# %% [markdown]
# <a href="https://colab.research.google.com/github/NayakAbhishek/NayakAbhishek/blob/main/TCS_Quantstats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install the necessary libraries
# !pip install pandas matplotlib seaborn quantstats yfinance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# Step 2: Import the necessary libraries
import pandas as pd
import quantstats as qs
import yfinance as yf

# %%
# Step 3: Load the TCS stock data into a Pandas DataFrame using yfinance
symbol = "TCS.NS"  # TCS stock symbol on the National Stock Exchange of India
data = yf.download(symbol, start="2001-01-01", end="2023-12-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Step 4: Calculate the performance metrics using the QuantStats library
qs.extend_pandas()
returns = data['Close'].pct_change()
qs.reports.html(returns, output='tcs_report.html', title='TCS Stock Report')
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.prod with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
# ...

# %%
# Step 5: Open the HTML report in the Jupyter Notebook
from IPython.core.display import HTML
HTML(filename='tcs_report.html')
# Out:
# <!-- generated by QuantStats for Python -->
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#     <title>Tearsheet (generated by QuantStats)</title>
#     <meta name="robots" content="noindex, nofollow">
#     <link rel="shortcut icon" href="https://qtpylib.io/favicon.ico" type="image/x-icon">
#     <style>
# ...
